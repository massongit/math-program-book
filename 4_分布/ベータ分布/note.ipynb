# %%
# %matplotlib inline
import math  # 標準のmathモジュール

import numpy as np  # NumPy
import pandas as pd  # Pandas

from matplotlib import pylab as plt  # Matplotlib

# matplotlibで日本語表示する為の指定
import japanize_matplotlib

# %%
# グラフ
from scipy.stats import beta

args = [(1, 1), (0.5, 0.5), (5, 1), (1, 5), (5, 5)]

for a, b in args:
    rv = beta(a, b)
    t = np.linspace(0, 1, 100)
    plt.plot(t, rv.pdf(t), label='a={0}, b={1}'.format(a, b))

plt.title('グラフ1 : ベータ分布')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
# グラフ
from scipy.stats import beta

args = [(3, 12), (7, 28), (20, 80)]

for a, b in args:
    rv = beta(a, b)
    t = np.linspace(0, 1, 100)
    plt.plot(t, rv.pdf(t), label='a={0}, b={1}'.format(a, b))

plt.title('グラフ2 : 20%で起こる事象の分布')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
from scipy.special import beta


def beta_distribution(x, a, b):
    """
    ベータ分布
    :param x: x
    :param a: a
    :param b: b
    :return: ベータ分布
    """
    numer = x ** (a - 1) * ((1 - x) ** (b - 1))
    denom = beta(a, b)
    return numer / denom


a = 7
b = 28
t = np.linspace(0, 1, 100)
y = [beta_distribution(x, a, b) for x in t]
plt.plot(t, y)

# %%
a = 7 + 6
b = 28 + 4
t = np.linspace(0, 1, 100)
y = [beta_distribution(x, a, b) for x in t]
plt.plot(t, y)

# %%
a = 7 + 6
b = 28 + 4
(a - 1) / (a + b - 2)
# Out:
# 0.27906976744186046

# %%
from scipy.stats import beta as beta_dist

a = 7 + 6
b = 28 + 4
t = np.linspace(0, 1, 100)

# SciPyのbeta分布関数
rv = beta_dist(a, b)
plt.plot(t, rv.pdf(t), color='red', alpha=0.5)

# 今回書いた自作関数
y2 = [beta_distribution(x, a, b) for x in t]
plt.plot(t, y2, color='blue', alpha=0.5)

# %%
# 正解例

from scipy.special import gamma


def beta_distribution_gamma(x, a, b):
    """
    ベータ分布 (ガンマ関数使用)
    :param x: x
    :param a: a
    :param b: b
    :return: ベータ分布
    """
    numer = gamma(a + b)
    denom = gamma(a) * gamma(b)
    return (numer / denom) * (x ** (a - 1)) * ((1 - x) ** (b - 1))


a = 7
b = 28
i = 0

while i < 100:
    a_ = a + i * 0.6
    b_ = b + i * 0.4
    m = (a_ - 1) / (a_ + b_ - 2)
    if m > 0.5:
        break
    else:
        i += 1

i * 0.6 + i * 0.4
# Out:
# 100.0
