# %%
# %matplotlib inline
import math  # 標準のmathモジュール

import numpy as np  # NumPy
import pandas as pd  # Pandas

from matplotlib import pylab as plt  # Matplotlib

# matplotlibで日本語表示する為の指定
import japanize_matplotlib

# %%
x = [170, 170, 176, 176, 183]  # 単位はcm

# %%
avg = 0

for i in range(1, n + 1):
    avg +=  # ここに∑の右に書かれた処理を書く

# %%
x[i]

# %%
avg = 0

for i in range(1, n + 1):
    avg += x[i]

# %%
x = [170, 170, 176, 176, 183]
n = len(x)
avg = 0

for i in range(n):
    avg += x[i]

(1 / n) * avg
# Out:
# 175.0

# %%
x = [170, 170, 176, 176, 183]
np.array(x).mean()
# Out:
# 175.0

# %%
# 結果
x = 0

for i in range(1, 10):
    for j in range(1, 10):
        x += i * j

x
# Out:
# 2025

# %%
# 正解例

x = 0

for i in range(1, 10):
    x += i

y = 0

for j in range(1, 10):
    y += j

x * y
# Out:
# 2025
