# %%
# %matplotlib inline
import math  # 標準のmathモジュール

import numpy as np  # NumPy
import pandas as pd  # Pandas

from matplotlib import pylab as plt  # Matplotlib

# matplotlibで日本語表示する為の指定
import japanize_matplotlib

# %%
# グラフ生成用
from scipy import special

t = np.linspace(1, 10, 100)

for i in range(1, 4):
    plt.plot(t, special.beta(t, i / 5.), label='b = {0:.1f}'.format(i / 5.))

plt.title("グラフ1: ベータ関数（正のみ）")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
# グラフ生成用
from scipy import special

t = np.linspace(-3, 5, 100)

for i in range(1, 4):
    plt.plot(t, special.beta(t, i), label='b = {0:.1f}'.format(i))

plt.title("グラフ2: ベータ関数（負も表示）")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.ylim((-20, 20))
# Out:
# (-20, 20)

# %%
from scipy import integrate


def beta(x, y, t):
    """
    t^(x-1) (1-t)^(y-1)
    :param x: x
    :param y: y
    :param t: t
    :return: t^(x-1) (1-t)^(y-1)
    """
    return t ** (x - 1) * ((1 - t) ** (y - 1))


b, abserr = integrate.quad(lambda t: beta(5, 2, t), 0, 1)
b
# Out:
# 0.033333333333333326

# %%
from scipy import special

special.beta(5, 2)
# Out:
# 0.03333333333333333

# %%
# 正解例

from scipy import special

x = 5
y = 2

(special.gamma(x) * special.gamma(y)) / special.gamma(x + y)
# Out:
# 0.03333333333333333
